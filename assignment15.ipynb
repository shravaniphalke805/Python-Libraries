# %% [markdown]
# <a href="https://colab.research.google.com/github/shravaniphalke805/Python-Libraries/blob/main/assignment15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e5df8ddb-eed7-48d9-9710-40c06a5f68d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5df8ddb-eed7-48d9-9710-40c06a5f68d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("/content/Countries.csv")

# %%
# First 5 rows
df[['country', 'capital_city', 'region', 'continent', 'population']].head()
# Out:
#        country      capital_city           region continent  population
# 0  Afghanistan             Kabul    Southern Asia      Asia    41128771
# 1      Albania            Tirana  Southern Europe    Europe     2775634
# 2      Algeria           Algiers  Northern Africa    Africa    44903225
# 3      Andorra  Andorra la Vella  Southern Europe    Europe       79824
# 4       Angola            Luanda    Middle Africa    Africa    35588987

# %%
df[['country', 'capital_city', 'region', 'continent', 'population']].tail()
# Out:
#                 country capital_city              region continent  population
# 189             Vietnam        Hanoi  South-Eastern Asia      Asia    98186856
# 190  West Bank and Gaza     Ramallah        Western Asia      Asia     5043612
# 191               Yemen       Sana'a        Western Asia      Asia    33696614
# 192              Zambia       Lusaka      Eastern Africa    Africa    20017675
# 193            Zimbabwe       Harare      Eastern Africa    Africa    16320537

# %%
df.shape
# Out:
# (194, 64)

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'currency', 'capital_city', 'region',
#        'continent', 'demonym', 'latitude', 'longitude', 'agricultural_land',
#        'forest_area', 'land_area', 'rural_land', 'urban_land',
#        'central_government_debt_pct_gdp', 'expense_pct_gdp', 'gdp',
#        'inflation', 'self_employed_pct', 'tax_revenue_pct_gdp',
#        'unemployment_pct', 'vulnerable_employment_pct',
#        'electricity_access_pct', 'alternative_nuclear_energy_pct',
#        'electricty_production_coal_pct',
#        'electricty_production_hydroelectric_pct',
#        'electricty_production_gas_pct', 'electricty_production_nuclear_pct',
#        'electricty_production_oil_pct', 'electricty_production_renewable_pct',
#        'energy_imports_pct', 'fossil_energy_consumption_pct',
#        'renewable_energy_consumption_pct', 'co2_emissions',
#        'methane_emissions', 'nitrous_oxide_emissions',
#        'greenhouse_other_emissions', 'urban_population_under_5m',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
df.describe()
# Out:
#          latitude   longitude  agricultural_land   forest_area     land_area  \
# count  194.000000  194.000000       1.930000e+02  1.940000e+02  1.940000e+02
# mean    18.975601   22.027491       2.454551e+05  2.086784e+05  6.675087e+05
# std     23.876225   66.396389       6.356268e+05  7.824926e+05  1.837107e+06
# min    -41.000000 -175.000000       4.000000e+00  0.000000e+00  2.027000e+00
# 25%      4.000000   -5.000000       6.464000e+03  3.331775e+03  2.355250e+04
# 50%     16.583333   21.500000       3.872780e+04  2.528925e+04  1.203750e+05
# 75%     40.000000   50.162500       2.150000e+05  1.236735e+05  5.237000e+05
# max     65.000000  178.000000       5.285080e+06  8.153120e+06  1.637690e+07
#
#          rural_land     urban_land  central_government_debt_pct_gdp  \
# count  1.940000e+02     194.000000                       120.000000
# mean   6.563711e+05    9777.116531                        66.759366
# std    1.811169e+06   42301.458421                        71.806247
# ...

# %%
df.dtypes
# Out:
# country              object
# country_long         object
# currency             object
# capital_city         object
# region               object
#                      ...
# democracy_score     float64
# democracy_type       object
# median_age          float64
# political_leader     object
# title                object
# Length: 64, dtype: object

# %%
df.isnull().sum()
# Out:
# country             0
# country_long        0
# currency            0
# capital_city        0
# region              0
#                    ..
# democracy_score     0
# democracy_type      0
# median_age          0
# political_leader    7
# title               7
# Length: 64, dtype: int64

# %%
df.nunique()
# Out:
# country             194
# country_long        194
# currency            142
# capital_city        194
# region               22
#                    ...
# democracy_score     146
# democracy_type        5
# median_age          143
# political_leader    187
# title                17
# Length: 64, dtype: int64

# %%
df.sample(5)
# Out:
#         country                 country_long                currency  \
# 176     Tunisia          Republic of Tunisia          Tunisian dinar
# 94      Lesotho           Kingdom of Lesotho            Lesotho loti
# 168    Tanzania  United Republic of Tanzania      Tanzanian shilling
# 116  Mozambique       Republic of Mozambique  New Mozambican metical
# 111     Moldova          Republic of Moldova            Moldovan leu
#
#     capital_city           region continent     demonym  latitude  longitude  \
# 176        Tunis  Northern Africa    Africa    Tunisian     34.00        9.0
# 94        Maseru  Southern Africa    Africa     Mosotho    -29.50       28.5
# 168       Dodoma   Eastern Africa    Africa   Tanzanian     -6.00       35.0
# 116       Maputo   Eastern Africa    Africa  Mozambican    -18.25       35.0
# 111     Chișinău   Eastern Europe    Europe    Moldovan     47.00       29.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# ...

# %%
df["country"].value_counts()
# Out:
# country
# Afghanistan           1
# Albania               1
# Algeria               1
# Andorra               1
# Angola                1
#                      ..
# Vietnam               1
# West Bank and Gaza    1
# Yemen                 1
# Zambia                1
# Zimbabwe              1
# Name: count, Length: 194, dtype: int64
