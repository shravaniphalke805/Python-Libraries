# %% [markdown]
# <a href="https://colab.research.google.com/github/shravaniphalke805/Python-Libraries/blob/main/Assignment18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-68e95e1e-7f98-4e2a-bed1-553d464b9a63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68e95e1e-7f98-4e2a-bed1-553d464b9a63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("ford_car_dataset - ford_car_dataset.csv")

# %%
# Display the first 10 rows
print("First 10 Rows:")
display(df.head(10))

# Display the last 5 rows
print("Last 5 Rows:")
display(df.tail(5))

# Display the shape of the dataset
print("Shape of the Dataset (Rows, Columns):")
print(df.shape)

# Display the data types of all columns
print("\nData Types of Columns:")
print(df.dtypes)

# Display complete dataset information
print("\nDataset Information:")
df.info()
# Out:
# First 10 Rows:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1   Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2   Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3  Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4  Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5  Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6    Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7  Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8    Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9   Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0
# Last 5 Rows:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# ...

# %%
# Observations:
# 1. The dataset consists of rows (records) and columns (features).
# 2. Each row represents information about one Ford car.
# 3. The dataset contains both numerical and categorical columns.
# 4. Numerical columns may include year, price, mileage, tax, mpg, and engineSize.
# 5. Categorical columns may include model, transmission, and fuelType.
# 6. The shape() function returns the total number of rows and columns.
# 7. The dtypes attribute shows the data type of each column.
# 8. The info() function provides additional details such as non-null values and memory usage.

# %%
# Q2. Missing & Duplicate Values

# Check missing values in each column
print("Missing Values in Each Column:")
print(df.isnull().sum())

# Check total missing values
print("\nTotal Missing Values:", df.isnull().sum().sum())

# Check duplicate rows
duplicate_rows = df.duplicated().sum()
print("\nNumber of Duplicate Rows:", duplicate_rows)

# Remove duplicate rows
df = df.drop_duplicates()

# Verify duplicates are removed
print("\nDuplicate Rows After Removal:", df.duplicated().sum())

# Display the new shape of the dataset
print("\nShape of Dataset After Removing Duplicates:")
print(df.shape)
# Out:
# Missing Values in Each Column:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64
#
# Total Missing Values: 0
#
# Number of Duplicate Rows: 154
#
# Duplicate Rows After Removal: 0
#
# Shape of Dataset After Removing Duplicates:
# (17812, 9)

# %%
# Observations:
# 1. The isnull().sum() function is used to count missing values in each column.
# 2. If the output is 0 for all columns, the dataset has no missing values.
# 3. The duplicated().sum() function counts the number of duplicate rows.
# 4. Duplicate rows were removed using drop_duplicates().
# 5. The shape was checked again to confirm that duplicate rows were removed.
# 6. Removing duplicate records improves data quality & prevents biased analysis.

# %%
# Q3. Statistical Summary

# Generate statistical summary for all numeric columns
print("Statistical Summary of Numeric Columns:")
display(df.describe())

# Minimum, Maximum, Mean, and Median for selected columns
key_columns = ['price', 'mileage', 'year']

print("\nSummary Statistics for Key Columns:\n")

for col in key_columns:
    print(f"Column: {col}")
    print(f"Minimum : {df[col].min()}")
    print(f"Maximum : {df[col].max()}")
    print(f"Mean    : {df[col].mean():.2f}")
    print(f"Median  : {df[col].median()}")
    print("-" * 30)
# Out:
# Statistical Summary of Numeric Columns:
#                year         price        mileage           tax           mpg  \
# count  17812.000000  17812.000000   17812.000000  17812.000000  17812.000000
# mean    2016.862396  12269.556310   23381.146362    113.315012     57.908696
# std        2.052039   4736.285417   19419.011045     62.034603     10.132696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000   10000.000000     30.000000     52.300000
# 50%     2017.000000  11288.000000   18277.000000    145.000000     58.900000
# 75%     2018.000000  15295.000000   31098.500000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17812.000000
# mean       1.350623
# std        0.432581
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000
# Summary Statistics for Key Columns:
#
# ...

# %%
# Observations:
# 1. The describe() function provides summary statistics for all numeric columns.
# 2. It includes count, mean, standard deviation, mini/maxi, quartiles &  values.
# 3. The mean represents the average value of each column.
# 4. The median (50th percentile) represents the middle value of the data.
# 5. The minimum and maximum values show the range of each feature.
# 6. These statistics help understand the distribution of car prices, mileage, and manufacturing years.

# %%
# Import required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# List of numeric columns to plot
numeric_columns = ['price', 'mileage', 'year', 'engineSize', 'mpg']

# Set figure size
plt.figure(figsize=(15, 10))

# Plot histograms
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(3, 2, i)
    sns.histplot(df[col], bins=30, kde=True, color='skyblue')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Observations:
# 1. The price distribution may be right-skewed, indicating that most cars
#    are moderately priced while a few are very expensive.
#
# 2. The mileage distribution often shows that many cars have lower to
#    medium mileage, with fewer cars having very high mileage.
#
# 3. The year distribution indicates that most vehicles belong to recent
#    manufacturing years.
#
# 4. The engineSize distribution shows that smaller engine sizes are more
#    common than larger engines.
#
# 5. The mpg (miles per gallon) distribution helps understand fuel efficiency.
#    Most vehicles are concentrated around average MPG values.
#
# 6. Histograms are useful for identifying the shape of the data,
#    detecting skewness, and spotting possible outliers.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select categorical columns
categorical_columns = ['fuelType', 'transmission', 'model']

# Set figure size
plt.figure(figsize=(18, 15))

# Plot count plots
for i, col in enumerate(categorical_columns, 1):
    plt.subplot(3, 1, i)
    sns.countplot(data=df, y=col, order=df[col].value_counts().index, palette='viridis', hue=col, legend=False)
    plt.title(f'Count Plot of {col}')
    plt.xlabel("Count")
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %%
# Observations:
# 1. The count plots show the frequency of each category in the dataset.
#
# 2. The most common fuel type represents the dominant fuel preference
#    among Ford vehicles in the dataset.
#
# 3. The transmission count plot indicates whether Manual or Automatic
#    vehicles are more common.
#
# 4. The model count plot identifies the most frequently listed Ford models,
#    indicating their popularity in the used car market.
#
# 5. Some categories have significantly fewer records, showing that
#    those models or fuel types are less common.
#
# 6. Market Trends:
#    - Popular models generally have higher availability in the market.
#    - The dominant fuel type reflects current consumer preferences.
#    - The transmission distribution indicates buyer demand for manual
#      or automatic vehicles.
#    - These plots help understand inventory distribution and market trends.

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Create correlation matrix
correlation_matrix = numeric_df.corr()
# Display correlation matrix
print("Correlation Matrix:")
display(correlation_matrix)

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5)

plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# Correlation of features with target variable (price)
print("\nCorrelation with Price:")
price_correlation = correlation_matrix['price'].sort_values(ascending=False)
print(price_correlation)
# Out:
# Correlation Matrix:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.635715 -0.708690  0.297183 -0.021702   -0.137582
# price       0.635715  1.000000 -0.530483  0.405969 -0.346263    0.411451
# mileage    -0.708690 -0.530483  1.000000 -0.257543  0.117697    0.214692
# tax         0.297183  0.405969 -0.257543  1.000000 -0.502343    0.185358
# mpg        -0.021702 -0.346263  0.117697 -0.502343  1.000000   -0.262239
# engineSize -0.137582  0.411451  0.214692  0.185358 -0.262239    1.000000
# Correlation with Price:
# price         1.000000
# year          0.635715
# engineSize    0.411451
# tax           0.405969
# mpg          -0.346263
# mileage      -0.530483
# Name: price, dtype: float64

# %%
# Observations:
# 1. The heatmap shows the relationship between different numeric features.
#
# 2. Correlation values range from -1 to +1:
#    - +1 indicates a strong positive relationship.
#    - -1 indicates a strong negative relationship.
#    - 0 indicates no linear relationship.
#
# 3. The 'price' column is considered the target variable.
#
# 4. Features with higher positive correlation with price have a stronger
#    influence on car prices.
#
# 5. Year generally shows a positive correlation with price because newer
#    cars tend to have higher prices.
#
# 6. Mileage usually shows a negative correlation with price because cars
#    with higher mileage often have lower prices.
#
# 7. Engine size may show a positive relationship with price because
#    vehicles with larger engines are often more expensive.
#
# 8. Highly correlated features can be useful for building machine learning
#    models for predicting car prices.

# %%
# Dependent Feature (Target Variable)
dependent_feature = 'price'

# Independent Features (Input Variables)
independent_features = [col for col in df.columns if col != dependent_feature]

print("Independent Features (Input Features):")
print(independent_features)

print("\nDependent Feature (Output/Target Feature):")
print(dependent_feature)
# Out:
# Independent Features (Input Features):
# ['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg', 'engineSize']
#
# Dependent Feature (Output/Target Feature):
# price

# %%
# Observations:
#
# 1. The dependent feature is 'price' because it is the value we want to
#    predict using machine learning models.
#
# 2. Independent features are all other columns that provide information
#    about the car and help predict its price.
#
# 3. Independent Features include:
#    - model
#    - year
#    - transmission
#    - mileage
#    - fuelType
#    - tax
#    - mpg
#    - engineSize
#
# 4. These features can influence the price of a used car.
#
# 5. Example:
#    - Newer cars (higher year) generally have higher prices.
#    - Higher mileage usually reduces car price.
#    - Engine size and model can affect the market value.
#
# 6. Therefore, 'price' is selected as the output variable, while all other
#    car-related attributes are selected as input variables.

# %%
# Display categorical columns before encoding
categorical_columns = df.select_dtypes(include=['object']).columns

print("Categorical Columns Before Encoding:")
print(categorical_columns)

# Show first 5 rows of two categorical columns before encoding
print("\nBefore Encoding:")
display(df[['fuelType', 'transmission']].head())

# Apply One Hot Encoding
df_encoded = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

# Show first 5 rows after encoding
print("\nAfter One Hot Encoding:")
display(df_encoded.head())

# Display new shape after encoding
print("\nShape Before Encoding:", df.shape)
print("Shape After Encoding:", df_encoded.shape)
# Out:
# Categorical Columns Before Encoding:
# Index(['model', 'transmission', 'fuelType'], dtype='object')
#
# Before Encoding:
#   fuelType transmission
# 0   Petrol    Automatic
# 1   Petrol       Manual
# 2   Petrol       Manual
# 3   Petrol       Manual
# 4   Petrol    Automatic
# After One Hot Encoding:
#    year  price  mileage  tax   mpg  engineSize  model_C-MAX  model_EcoSport  \
# 0  2017  12000    15944  150  57.7         1.0        False           False
# 1  2018  14000     9083  150  57.7         1.0        False           False
# 2  2017  13000    12456  150  57.7         1.0        False           False
# 3  2019  17500    10460  145  40.3         1.5        False           False
# 4  2019  16500     1482  145  48.7         1.0        False           False
#
#    model_Edge  model_Escort  ...  model_Streetka  model_Tourneo Connect  \
# 0       False         False  ...           False                  False
# ...

# %%
# Import StandardScaler
from sklearn.preprocessing import StandardScaler

# Select numeric independent features
numeric_features = df_encoded.drop('price', axis=1).select_dtypes(include=['int64', 'float64'])

# Initialize StandardScaler
scaler = StandardScaler()

# Apply standard scaling
scaled_data = scaler.fit_transform(numeric_features)

# Convert scaled data back to DataFrame
scaled_df = pd.DataFrame(
    scaled_data,
    columns=numeric_features.columns
)

# Display first 5 rows of scaled data
print("First 5 Rows of Scaled Data:")
display(scaled_df.head())
# Out:
# First 5 Rows of Scaled Data:
#        year   mileage       tax       mpg  engineSize
# 0  0.067059 -0.382994  0.591380 -0.020597   -0.810561
# 1  0.554393 -0.736317  0.591380 -0.020597   -0.810561
# 2  0.067059 -0.562616  0.591380 -0.020597   -0.810561
# 3  1.041726 -0.665405  0.510777 -1.737858    0.345325
# 4  1.041726 -1.127749  0.510777 -0.908836   -0.810561

# %%
# Q10. Complete Preprocessing Pipeline

# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# 1. Load Dataset
# Upload and load dataset (if required in Colab)
from google.colab import files
uploaded = files.upload()
df = pd.read_csv(next(iter(uploaded)))
print("Initial Dataset:")
display(df.head())

# 2. Data Cleaning
# Check missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Remove duplicate rows
print("\nDuplicate Rows Before Removal:", df.duplicated().sum())
df = df.drop_duplicates()
print("Duplicate Rows After Removal:", df.duplicated().sum())
# Check dataset after cleaning
print("\nDataset Shape After Cleaning:")
print(df.shape)

# 3. Exploratory Data Analysis (EDA)
# Numeric columns
numeric_columns = ['price', 'mileage', 'year', 'engineSize', 'mpg']

# Histograms
plt.figure(figsize=(15,10))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(3,2,i)
    sns.histplot(df[col], bins=30, kde=True, color='blue')
    plt.title(f'Histogram of {col}')
plt.tight_layout()
plt.show()

# Count plots for categorical features
categorical_columns = df.select_dtypes(include='object').columns
plt.figure(figsize=(15,12))

for i, col in enumerate(categorical_columns, 1):
    plt.subplot(len(categorical_columns),1,i)
    sns.countplot(
        data=df,
        y=col,
        order=df[col].value_counts().index,
        palette='viridis',
        hue=col, legend=False)
    plt.title(f'Count Plot of {col}')
plt.tight_layout()
plt.show()

# Correlation Heatmap
plt.figure(figsize=(10,6))

correlation = df.select_dtypes(
    include=['int64','float64']
).corr()

sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm',
    fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# 4. Identify Input and Output Features
# Target variable
target = 'price'

# Input features
X = df.drop(target, axis=1)
# Output feature
y = df[target]
print("\nIndependent Features:")
print(X.columns)
print("\nDependent Feature:")
print(target)

# 5. Encode Categorical Variable
# One Hot Encoding
X_encoded = pd.get_dummies(
    X,
    drop_first=True)
print("\nShape After Encoding:")
print(X_encoded.shape)

# 6. Scale Numeric Features
# Select numeric columns
numeric_features = X_encoded.select_dtypes(
    include=['int64','float64']
).columns

# Apply Standard Scaling
scaler = StandardScaler()
X_encoded[numeric_features] = scaler.fit_transform(
    X_encoded[numeric_features])

# Display first 5 rows after scaling
print("\nFirst 5 Rows After Scaling:")
display(X_encoded.head())

# Final dataset information
print("\nFinal Input Data Shape:")
print(X_encoded.shape)
print("\nTarget Data Shape:")
print(y.shape)
# Out:
#      <input type="file" id="files-b5437c76-92b8-42c2-a8e1-d440df8bbeae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5437c76-92b8-42c2-a8e1-d440df8bbeae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
